# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

# %% [markdown]
# # Data visualization

# %%
# Out:
# array([112,  88])

# %% [markdown]
# # Clusterization

# %%
# km = KMeans(n_clusters = 5, init = 'k-means++', n_init = 10)
# y_means = km.fit_predict(x)

# plt.scatter(x[y_means == 0, 0], x[y_means == 0, 1], s = 100, c = 'pink', label = 'не целевые')
# plt.scatter(x[y_means == 1, 0], x[y_means == 1, 1], s = 100, c = 'yellow', label = 'любители шоппинга')
# plt.scatter(x[y_means == 2, 0], x[y_means == 2, 1], s = 100, c = 'cyan', label = 'средний класс')
# plt.scatter(x[y_means == 3, 0], x[y_means == 3, 1], s = 100, c = 'magenta', label = 'супер золотые клиенты')
# plt.scatter(x[y_means == 4, 0], x[y_means == 4, 1], s = 100, c = 'orange', label = 'жлобы')
# plt.scatter(km.cluster_centers_[:,0], km.cluster_centers_[:, 1], s = 50, c = 'blue' , label = 'centeroid')

# plt.style.use('fivethirtyeight')
# plt.title('K Means Clustering', fontsize = 20)
# plt.xlabel('Annual Income')
# plt.ylabel('Spending Score')
# plt.legend()
# plt.grid()
# plt.show()
